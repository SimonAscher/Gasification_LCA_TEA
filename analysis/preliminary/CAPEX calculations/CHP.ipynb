# %% [markdown]
# # CAPEX of CHP plants

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from functions.general.utility import get_project_root
from functions.TEA import convert_currency_annual_average
from functions.TEA.scaling import CEPCI_scale

# %% [markdown]
# ### Load Data and data wrangling
# Get all data into same base year and currency.

# %%
# Load and display data
root_dir = get_project_root()
data_file = "CAPEX_CHP.csv"
data_file_path = os.path.join(root_dir, "data", data_file)
df = pd.read_csv(data_file_path)
df
# Out:
#                                     Process Reference                    Type  \
# 0    Steam turbine for biomass oxycombustion with CCS           steam turbine
# 1       Steam turbine for coal oxycombustion with CCS           steam turbine
# 2                                     Stirling Engine         stirling engine
# 3      Piston Engine (Skorek-Osikowska et al. Case 1)           piston engine
# 4      Piston Engine (Skorek-Osikowska et al. Case 2)           piston engine
# 5   Piston Engine (Skorek-Osikowska et al. Example 1)           piston engine
# 6   Piston Engine (Skorek-Osikowska et al. Example 2)           piston engine
# 7   Piston Engine based electricity generation system           piston engine
# 8                      Steam Turbine and Steam system           steam turbine
# 9   Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 10  Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 11  Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 12  Steam turbine + accessories  (Shell IGCC and E...           steam turbine
# 13                                        Steam cycle           steam turbine
# 14                                        Gas turbine             gas turbine
# 15          Organice Rankine cycle + syngas combustor  organice rankine cycle
# 16                       Equipment Cost - Gas turbine             gas turbine
#
#            CAPEX Currency  Plant size [kWel]  Reference Year Country  \
# 0   5.942000e+08      GBP          598000.00            2018      UK
# 1   7.745000e+08      GBP         1097700.00            2018      UK
# 2   1.020600e+06      GBP             255.15            2017      UK
# 3   5.798732e+05      EUR             322.21            2014  Poland
# 4   2.078835e+06      EUR            1154.02            2014  Poland
# 5   1.795602e+05      EUR             100.00            2014  Poland
# 6   9.010117e+06      EUR            5000.00            2014  Poland
# 7   4.228242e+06      EUR            1400.08            2014  Poland
# 8   4.584500e+07      USD           64411.00            2007     USA
# 9   8.444800e+07      USD          464000.00            2019     USA
# 10  9.465600e+07      USD          464000.00            2019     USA
# 11  1.178560e+08      USD          464000.00            2019     USA
# 12  4.725700e+07      USD          301000.00            2019     USA
# 13  6.670000e+07      USD          275000.00            2007     USA
# 14  7.320000e+07      USD          266000.00            2007     USA
# 15  8.900000e+05      EUR             400.00            2015   Italy
# 16  2.500000e+06      USD             419.00            2020     USA
#
#     Scaling factor  Balance of plant costs/Overall installation factor  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# 5              NaN                                                NaN
# 6              NaN                                                NaN
# 7              NaN                                                NaN
# 8              NaN                                                NaN
# 9              NaN                                                NaN
# 10             NaN                                                NaN
# 11             NaN                                                NaN
# 12             NaN                                                NaN
# 13            0.67                                               1.15
# 14            0.75                                               1.27
# 15             NaN                                                NaN
# 16             NaN                                                NaN
#
#                                              Comments  \
# 0   Case 9; reference year estimated based on year...
# 1   Case 9; reference year estimated based on year...
# 2          CAPEX range: 3000-7200 (year 2030 vs 2012)
# 3   cost estimated from equation 25; power of indi...
# 4   cost estimated from equation 25; power of indi...
# 5   cost estimated from equation 25; power of indi...
# 6   cost estimated from equation 25; power of indi...
# 7   calculated from equations given in reference f...
# 8   also includes steam generation system,  TIC (t...
# 9                                          lower case
# 10                                        middle case
# 11                                         upper case
# 12           middle case only as too little variation
# 13                                                NaN
# 14                                                NaN
# 15                 alternatively 18 tonne SRF per day
# 16                      altneratively 876 tonnes/year
#
#                                             Reference
# 0   https://assets.publishing.service.gov.uk/gover...
# 1   https://assets.publishing.service.gov.uk/gover...
# 2        https://doi.org/10.1016/j.energy.2017.11.106
# 3                        10.1016/j.energy.2014.01.015
# 4                        10.1016/j.energy.2014.01.015
# 5                        10.1016/j.energy.2014.01.015
# 6                        10.1016/j.energy.2014.01.015
# 7   10.1016/j.energy.2014.01.015 AND https://doi.o...
# 8   Process Design and Economics for Conversion of...
# 9   COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...
# 10  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...
# 11  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...
# 12  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...
# 13        Fischer-tropsch fuels from coal and biomass
# 14        Fischer-tropsch fuels from coal and biomass
# 15                       10.1016/j.fuproc.2014.11.003
# 16  https://doi.org/10.1016/j.compchemeng.2020.106758

# %%
# Convert all values to same currency and update to most recent CEPCI value
updated_currency = "GBP"
updated_CEPCI_year = 2020
CAPEX_currency_scaled = []
CAPEX_currency_CEPCI_scaled = []

for row_no in df.index:
    CAPEX_currency_scaled.append(convert_currency_annual_average(value=df["CAPEX"][row_no], year=df["Reference Year"][row_no], base_currency=df["Currency"][row_no], converted_currency=updated_currency))
    CAPEX_currency_CEPCI_scaled.append(CEPCI_scale(base_year=df["Reference Year"][row_no], design_year=updated_CEPCI_year, value=CAPEX_currency_scaled[row_no]))
print("Currency scaled values:", CAPEX_currency_scaled)
print("Currency and CEPCI scaled values:", CAPEX_currency_CEPCI_scaled)
# Out:
# Currency scaled values: [594200000.0, 774500000.0, 1020600.0, 467462.92899784114, 1675845.9952830246, 144751.8653079781, 7263477.197727552, 3408583.643982904, 22901075.061465755, 66171706.46163287, 74170484.1657863, 92349524.40249862, 37029607.95113424, 33318828.80575343, 36565791.13315069, 646354.0876712329, 1949010.5464480876]
# Currency and CEPCI scaled values: [588682639.6949096, 767308489.4710661, 1074552.422907489, 484827.4606426143, 1738097.5215789052, 150128.86568567422, 7533288.7096723, 3535200.012636322, 26043761.60872819, 63852704.47484761, 71571163.2575215, 89113115.03632578, 35731897.20736872, 37891130.96961872, 41583669.96965653, 693600.1569388679, 1949010.5464480876]

# %%
# Add (i) currency and (ii) currency + CEPCI scaled values to dataframe
currency_scaled_label = "CAPEX_" + updated_currency
currency_and_CEPCI_scaled_label = "CAPEX_" + updated_currency + "_CEPCI_" + str(updated_CEPCI_year)

df[currency_scaled_label] = CAPEX_currency_scaled
df[currency_and_CEPCI_scaled_label] = CAPEX_currency_CEPCI_scaled
df
# Out:
#                                     Process Reference                    Type  \
# 0    Steam turbine for biomass oxycombustion with CCS           steam turbine
# 1       Steam turbine for coal oxycombustion with CCS           steam turbine
# 2                                     Stirling Engine         stirling engine
# 3      Piston Engine (Skorek-Osikowska et al. Case 1)           piston engine
# 4      Piston Engine (Skorek-Osikowska et al. Case 2)           piston engine
# 5   Piston Engine (Skorek-Osikowska et al. Example 1)           piston engine
# 6   Piston Engine (Skorek-Osikowska et al. Example 2)           piston engine
# 7   Piston Engine based electricity generation system           piston engine
# 8                      Steam Turbine and Steam system           steam turbine
# 9   Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 10  Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 11  Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 12  Steam turbine + accessories  (Shell IGCC and E...           steam turbine
# 13                                        Steam cycle           steam turbine
# 14                                        Gas turbine             gas turbine
# 15          Organice Rankine cycle + syngas combustor  organice rankine cycle
# 16                       Equipment Cost - Gas turbine             gas turbine
#
#            CAPEX Currency  Plant size [kWel]  Reference Year Country  \
# 0   5.942000e+08      GBP          598000.00            2018      UK
# 1   7.745000e+08      GBP         1097700.00            2018      UK
# 2   1.020600e+06      GBP             255.15            2017      UK
# 3   5.798732e+05      EUR             322.21            2014  Poland
# 4   2.078835e+06      EUR            1154.02            2014  Poland
# 5   1.795602e+05      EUR             100.00            2014  Poland
# 6   9.010117e+06      EUR            5000.00            2014  Poland
# 7   4.228242e+06      EUR            1400.08            2014  Poland
# 8   4.584500e+07      USD           64411.00            2007     USA
# 9   8.444800e+07      USD          464000.00            2019     USA
# 10  9.465600e+07      USD          464000.00            2019     USA
# 11  1.178560e+08      USD          464000.00            2019     USA
# 12  4.725700e+07      USD          301000.00            2019     USA
# 13  6.670000e+07      USD          275000.00            2007     USA
# 14  7.320000e+07      USD          266000.00            2007     USA
# 15  8.900000e+05      EUR             400.00            2015   Italy
# 16  2.500000e+06      USD             419.00            2020     USA
#
#     Scaling factor  Balance of plant costs/Overall installation factor  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# 5              NaN                                                NaN
# 6              NaN                                                NaN
# 7              NaN                                                NaN
# 8              NaN                                                NaN
# 9              NaN                                                NaN
# 10             NaN                                                NaN
# 11             NaN                                                NaN
# 12             NaN                                                NaN
# 13            0.67                                               1.15
# 14            0.75                                               1.27
# 15             NaN                                                NaN
# 16             NaN                                                NaN
#
#                                              Comments  \
# 0   Case 9; reference year estimated based on year...
# 1   Case 9; reference year estimated based on year...
# 2          CAPEX range: 3000-7200 (year 2030 vs 2012)
# 3   cost estimated from equation 25; power of indi...
# 4   cost estimated from equation 25; power of indi...
# 5   cost estimated from equation 25; power of indi...
# 6   cost estimated from equation 25; power of indi...
# 7   calculated from equations given in reference f...
# 8   also includes steam generation system,  TIC (t...
# 9                                          lower case
# 10                                        middle case
# 11                                         upper case
# 12           middle case only as too little variation
# 13                                                NaN
# 14                                                NaN
# 15                 alternatively 18 tonne SRF per day
# 16                      altneratively 876 tonnes/year
#
#                                             Reference     CAPEX_GBP  \
# 0   https://assets.publishing.service.gov.uk/gover...  5.942000e+08
# 1   https://assets.publishing.service.gov.uk/gover...  7.745000e+08
# 2        https://doi.org/10.1016/j.energy.2017.11.106  1.020600e+06
# 3                        10.1016/j.energy.2014.01.015  4.674629e+05
# 4                        10.1016/j.energy.2014.01.015  1.675846e+06
# 5                        10.1016/j.energy.2014.01.015  1.447519e+05
# 6                        10.1016/j.energy.2014.01.015  7.263477e+06
# 7   10.1016/j.energy.2014.01.015 AND https://doi.o...  3.408584e+06
# 8   Process Design and Economics for Conversion of...  2.290108e+07
# 9   COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  6.617171e+07
# 10  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  7.417048e+07
# 11  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  9.234952e+07
# 12  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  3.702961e+07
# 13        Fischer-tropsch fuels from coal and biomass  3.331883e+07
# 14        Fischer-tropsch fuels from coal and biomass  3.656579e+07
# 15                       10.1016/j.fuproc.2014.11.003  6.463541e+05
# 16  https://doi.org/10.1016/j.compchemeng.2020.106758  1.949011e+06
#
#     CAPEX_GBP_CEPCI_2020
# 0           5.886826e+08
# 1           7.673085e+08
# 2           1.074552e+06
# 3           4.848275e+05
# 4           1.738098e+06
# 5           1.501289e+05
# 6           7.533289e+06
# 7           3.535200e+06
# 8           2.604376e+07
# 9           6.385270e+07
# 10          7.157116e+07
# 11          8.911312e+07
# 12          3.573190e+07
# 13          3.789113e+07
# 14          4.158367e+07
# 15          6.936002e+05
# 16          1.949011e+06

# %% [markdown]
# ### Plot complete data set

# %%
# Plot all data
sns.scatterplot(data=df, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
plt.xlabel("Plant size [kW${_{el}}$]")
plt.ylabel("CAPEX [GBP]")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Data points are extremely spaced.
# Split data set into a smaller and more medium-sized plants.

# %% [markdown]
# ### Plants of small size (i.e. < 2000 kWel)

# %%
# Get df of plants with a size smaller than 2 MWel
df_small = df[df["Plant size [kWel]"] < 2000].copy()
df_small
# Out:
#                                     Process Reference                    Type  \
# 2                                     Stirling Engine         stirling engine
# 3      Piston Engine (Skorek-Osikowska et al. Case 1)           piston engine
# 4      Piston Engine (Skorek-Osikowska et al. Case 2)           piston engine
# 5   Piston Engine (Skorek-Osikowska et al. Example 1)           piston engine
# 7   Piston Engine based electricity generation system           piston engine
# 15          Organice Rankine cycle + syngas combustor  organice rankine cycle
# 16                       Equipment Cost - Gas turbine             gas turbine
#
#          CAPEX Currency  Plant size [kWel]  Reference Year Country  \
# 2   1020600.00      GBP             255.15            2017      UK
# 3    579873.17      EUR             322.21            2014  Poland
# 4   2078834.64      EUR            1154.02            2014  Poland
# 5    179560.17      EUR             100.00            2014  Poland
# 7   4228241.60      EUR            1400.08            2014  Poland
# 15   890000.00      EUR             400.00            2015   Italy
# 16  2500000.00      USD             419.00            2020     USA
#
#     Scaling factor  Balance of plant costs/Overall installation factor  \
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# 5              NaN                                                NaN
# 7              NaN                                                NaN
# 15             NaN                                                NaN
# 16             NaN                                                NaN
#
#                                              Comments  \
# 2          CAPEX range: 3000-7200 (year 2030 vs 2012)
# 3   cost estimated from equation 25; power of indi...
# 4   cost estimated from equation 25; power of indi...
# 5   cost estimated from equation 25; power of indi...
# 7   calculated from equations given in reference f...
# 15                 alternatively 18 tonne SRF per day
# 16                      altneratively 876 tonnes/year
#
#                                             Reference     CAPEX_GBP  \
# 2        https://doi.org/10.1016/j.energy.2017.11.106  1.020600e+06
# 3                        10.1016/j.energy.2014.01.015  4.674629e+05
# 4                        10.1016/j.energy.2014.01.015  1.675846e+06
# 5                        10.1016/j.energy.2014.01.015  1.447519e+05
# 7   10.1016/j.energy.2014.01.015 AND https://doi.o...  3.408584e+06
# 15                       10.1016/j.fuproc.2014.11.003  6.463541e+05
# 16  https://doi.org/10.1016/j.compchemeng.2020.106758  1.949011e+06
#
#     CAPEX_GBP_CEPCI_2020
# 2           1.074552e+06
# 3           4.848275e+05
# 4           1.738098e+06
# 5           1.501289e+05
# 7           3.535200e+06
# 15          6.936002e+05
# 16          1.949011e+06

# %%
# Plot data - differentiate by type
sns.scatterplot(data=df_small, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
plt.xlabel("Plant size [kW${_{el}}$]")
plt.ylabel("CAPEX [GBP]")
plt.xticks(rotation=45)
plt.show()

# %%
# Plot data - differentiate by Reference
small_df_by_ref = sns.scatterplot(data=df_small, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Reference")
plt.setp(small_df_by_ref.get_legend().get_texts(), fontsize='6')
plt.setp(small_df_by_ref.get_legend().get_title(), fontsize='9')

plt.xlabel("Plant size [kW${_{el}}$]")
plt.ylabel("CAPEX [GBP]")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Plants of larger size (i.e. > 2,000 kWel)

# %%
# Get df of plants with a size larger than 2 MWel
df_large = df[df["Plant size [kWel]"] > 2000].copy()
df_large
# Out:
#                                     Process Reference           Type  \
# 0    Steam turbine for biomass oxycombustion with CCS  steam turbine
# 1       Steam turbine for coal oxycombustion with CCS  steam turbine
# 6   Piston Engine (Skorek-Osikowska et al. Example 2)  piston engine
# 8                      Steam Turbine and Steam system  steam turbine
# 9   Combustion turbine + accessories  (Shell IGCC ...    gas turbine
# 10  Combustion turbine + accessories  (Shell IGCC ...    gas turbine
# 11  Combustion turbine + accessories  (Shell IGCC ...    gas turbine
# 12  Steam turbine + accessories  (Shell IGCC and E...  steam turbine
# 13                                        Steam cycle  steam turbine
# 14                                        Gas turbine    gas turbine
#
#            CAPEX Currency  Plant size [kWel]  Reference Year Country  \
# 0   5.942000e+08      GBP           598000.0            2018      UK
# 1   7.745000e+08      GBP          1097700.0            2018      UK
# 6   9.010117e+06      EUR             5000.0            2014  Poland
# 8   4.584500e+07      USD            64411.0            2007     USA
# 9   8.444800e+07      USD           464000.0            2019     USA
# 10  9.465600e+07      USD           464000.0            2019     USA
# 11  1.178560e+08      USD           464000.0            2019     USA
# 12  4.725700e+07      USD           301000.0            2019     USA
# 13  6.670000e+07      USD           275000.0            2007     USA
# 14  7.320000e+07      USD           266000.0            2007     USA
#
#     Scaling factor  Balance of plant costs/Overall installation factor  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 6              NaN                                                NaN
# 8              NaN                                                NaN
# 9              NaN                                                NaN
# 10             NaN                                                NaN
# 11             NaN                                                NaN
# 12             NaN                                                NaN
# 13            0.67                                               1.15
# 14            0.75                                               1.27
#
#                                              Comments  \
# 0   Case 9; reference year estimated based on year...
# 1   Case 9; reference year estimated based on year...
# 6   cost estimated from equation 25; power of indi...
# 8   also includes steam generation system,  TIC (t...
# 9                                          lower case
# 10                                        middle case
# 11                                         upper case
# 12           middle case only as too little variation
# 13                                                NaN
# 14                                                NaN
#
#                                             Reference     CAPEX_GBP  \
# 0   https://assets.publishing.service.gov.uk/gover...  5.942000e+08
# 1   https://assets.publishing.service.gov.uk/gover...  7.745000e+08
# 6                        10.1016/j.energy.2014.01.015  7.263477e+06
# 8   Process Design and Economics for Conversion of...  2.290108e+07
# 9   COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  6.617171e+07
# 10  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  7.417048e+07
# 11  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  9.234952e+07
# 12  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  3.702961e+07
# 13        Fischer-tropsch fuels from coal and biomass  3.331883e+07
# 14        Fischer-tropsch fuels from coal and biomass  3.656579e+07
#
#     CAPEX_GBP_CEPCI_2020
# 0           5.886826e+08
# 1           7.673085e+08
# 6           7.533289e+06
# 8           2.604376e+07
# 9           6.385270e+07
# 10          7.157116e+07
# 11          8.911312e+07
# 12          3.573190e+07
# 13          3.789113e+07
# 14          4.158367e+07

# %%
# Plot all large data - differentiate by type
sns.scatterplot(data=df_large, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
plt.xlabel("Plant size [kW${_{el}}$]")
plt.ylabel("CAPEX [GBP]")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Plants of medium size (i.e. > 5,000 kWel and < 500,000)
# Discard very lage plants - they seem to be outliers.
# Also discard 5,000 kWel plant as its too far off from rest of data.

# %%
# Get df of plants with a medium size
df_medium = df[(df["Plant size [kWel]"] > 5000) & (df["Plant size [kWel]"] <= 500000)].copy()
df_medium
# Out:
#                                     Process Reference           Type  \
# 8                      Steam Turbine and Steam system  steam turbine
# 9   Combustion turbine + accessories  (Shell IGCC ...    gas turbine
# 10  Combustion turbine + accessories  (Shell IGCC ...    gas turbine
# 11  Combustion turbine + accessories  (Shell IGCC ...    gas turbine
# 12  Steam turbine + accessories  (Shell IGCC and E...  steam turbine
# 13                                        Steam cycle  steam turbine
# 14                                        Gas turbine    gas turbine
#
#           CAPEX Currency  Plant size [kWel]  Reference Year Country  \
# 8    45845000.0      USD            64411.0            2007     USA
# 9    84448000.0      USD           464000.0            2019     USA
# 10   94656000.0      USD           464000.0            2019     USA
# 11  117856000.0      USD           464000.0            2019     USA
# 12   47257000.0      USD           301000.0            2019     USA
# 13   66700000.0      USD           275000.0            2007     USA
# 14   73200000.0      USD           266000.0            2007     USA
#
#     Scaling factor  Balance of plant costs/Overall installation factor  \
# 8              NaN                                                NaN
# 9              NaN                                                NaN
# 10             NaN                                                NaN
# 11             NaN                                                NaN
# 12             NaN                                                NaN
# 13            0.67                                               1.15
# 14            0.75                                               1.27
#
#                                              Comments  \
# 8   also includes steam generation system,  TIC (t...
# 9                                          lower case
# 10                                        middle case
# 11                                         upper case
# 12           middle case only as too little variation
# 13                                                NaN
# 14                                                NaN
#
#                                             Reference     CAPEX_GBP  \
# 8   Process Design and Economics for Conversion of...  2.290108e+07
# 9   COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  6.617171e+07
# 10  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  7.417048e+07
# 11  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  9.234952e+07
# 12  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  3.702961e+07
# 13        Fischer-tropsch fuels from coal and biomass  3.331883e+07
# 14        Fischer-tropsch fuels from coal and biomass  3.656579e+07
#
#     CAPEX_GBP_CEPCI_2020
# 8           2.604376e+07
# 9           6.385270e+07
# 10          7.157116e+07
# 11          8.911312e+07
# 12          3.573190e+07
# 13          3.789113e+07
# 14          4.158367e+07

# %%
# Plot all medium data - differentiate by type
sns.scatterplot(data=df_medium, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
plt.xlabel("Plant size [kW${_{el}}$]")
plt.ylabel("CAPEX [GBP]")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Combine small and medium sized plant data set

# %%
small_med_df = pd.concat([df_small,df_medium])
small_med_df
# Out:
#                                     Process Reference                    Type  \
# 2                                     Stirling Engine         stirling engine
# 3      Piston Engine (Skorek-Osikowska et al. Case 1)           piston engine
# 4      Piston Engine (Skorek-Osikowska et al. Case 2)           piston engine
# 5   Piston Engine (Skorek-Osikowska et al. Example 1)           piston engine
# 7   Piston Engine based electricity generation system           piston engine
# 15          Organice Rankine cycle + syngas combustor  organice rankine cycle
# 16                       Equipment Cost - Gas turbine             gas turbine
# 8                      Steam Turbine and Steam system           steam turbine
# 9   Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 10  Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 11  Combustion turbine + accessories  (Shell IGCC ...             gas turbine
# 12  Steam turbine + accessories  (Shell IGCC and E...           steam turbine
# 13                                        Steam cycle           steam turbine
# 14                                        Gas turbine             gas turbine
#
#            CAPEX Currency  Plant size [kWel]  Reference Year Country  \
# 2   1.020600e+06      GBP             255.15            2017      UK
# 3   5.798732e+05      EUR             322.21            2014  Poland
# 4   2.078835e+06      EUR            1154.02            2014  Poland
# 5   1.795602e+05      EUR             100.00            2014  Poland
# 7   4.228242e+06      EUR            1400.08            2014  Poland
# 15  8.900000e+05      EUR             400.00            2015   Italy
# 16  2.500000e+06      USD             419.00            2020     USA
# 8   4.584500e+07      USD           64411.00            2007     USA
# 9   8.444800e+07      USD          464000.00            2019     USA
# 10  9.465600e+07      USD          464000.00            2019     USA
# 11  1.178560e+08      USD          464000.00            2019     USA
# 12  4.725700e+07      USD          301000.00            2019     USA
# 13  6.670000e+07      USD          275000.00            2007     USA
# 14  7.320000e+07      USD          266000.00            2007     USA
#
#     Scaling factor  Balance of plant costs/Overall installation factor  \
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# 5              NaN                                                NaN
# 7              NaN                                                NaN
# 15             NaN                                                NaN
# 16             NaN                                                NaN
# 8              NaN                                                NaN
# 9              NaN                                                NaN
# 10             NaN                                                NaN
# 11             NaN                                                NaN
# 12             NaN                                                NaN
# 13            0.67                                               1.15
# 14            0.75                                               1.27
#
#                                              Comments  \
# 2          CAPEX range: 3000-7200 (year 2030 vs 2012)
# 3   cost estimated from equation 25; power of indi...
# 4   cost estimated from equation 25; power of indi...
# 5   cost estimated from equation 25; power of indi...
# 7   calculated from equations given in reference f...
# 15                 alternatively 18 tonne SRF per day
# 16                      altneratively 876 tonnes/year
# 8   also includes steam generation system,  TIC (t...
# 9                                          lower case
# 10                                        middle case
# 11                                         upper case
# 12           middle case only as too little variation
# 13                                                NaN
# 14                                                NaN
#
#                                             Reference     CAPEX_GBP  \
# 2        https://doi.org/10.1016/j.energy.2017.11.106  1.020600e+06
# 3                        10.1016/j.energy.2014.01.015  4.674629e+05
# 4                        10.1016/j.energy.2014.01.015  1.675846e+06
# 5                        10.1016/j.energy.2014.01.015  1.447519e+05
# 7   10.1016/j.energy.2014.01.015 AND https://doi.o...  3.408584e+06
# 15                       10.1016/j.fuproc.2014.11.003  6.463541e+05
# 16  https://doi.org/10.1016/j.compchemeng.2020.106758  1.949011e+06
# 8   Process Design and Economics for Conversion of...  2.290108e+07
# 9   COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  6.617171e+07
# 10  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  7.417048e+07
# 11  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  9.234952e+07
# 12  COST AND PERFORMANCE BASELINE FOR FOSSIL ENERG...  3.702961e+07
# 13        Fischer-tropsch fuels from coal and biomass  3.331883e+07
# 14        Fischer-tropsch fuels from coal and biomass  3.656579e+07
#
#     CAPEX_GBP_CEPCI_2020
# 2           1.074552e+06
# 3           4.848275e+05
# 4           1.738098e+06
# 5           1.501289e+05
# 7           3.535200e+06
# 15          6.936002e+05
# 16          1.949011e+06
# 8           2.604376e+07
# 9           6.385270e+07
# 10          7.157116e+07
# 11          8.911312e+07
# 12          3.573190e+07
# 13          3.789113e+07
# 14          4.158367e+07

# %%
# Plot all medium data - differentiate by type
sns.scatterplot(data=small_med_df, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
plt.xlabel("Plant size [kW${_{el}}$]")
plt.ylabel("CAPEX [GBP]")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Can identify 2 clusters here - small data set and larger data set - fit two individual models.

# %% [markdown]
# ### Add regression fit to plots

# %%
def plot_scatter_with_fit(dataset):

    fit_coefficients = np.polyfit(x=dataset["Plant size [kWel]"] ,y=dataset[currency_and_CEPCI_scaled_label], deg=1)
    fit_coefficients_slope = fit_coefficients[0]
    fit_coefficients_intercept = fit_coefficients[1]

    x_values_fit = [min(dataset["Plant size [kWel]"]), max(dataset["Plant size [kWel]"])]
    y_values_fit = [fit_coefficients_slope*values + fit_coefficients_intercept  for values in x_values_fit]

    # Plot with fit
    sns.scatterplot(data=dataset, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
    plt.plot(x_values_fit, y_values_fit)
    plt.xlabel("Plant size [kW${_{el}}$]")
    plt.ylabel("CAPEX [GBP]")
    plt.xticks(rotation=45)
    plt.show()

    return x_values_fit, y_values_fit

small_fitted_values = plot_scatter_with_fit(df_small)
medium_fitted_values = plot_scatter_with_fit(df_medium)

# %%
# Plot both fits
fig, ax = plt.subplots(figsize=(30,20))
sns.scatterplot(data=small_med_df, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
plt.plot(small_fitted_values[0], small_fitted_values[1])
plt.plot(medium_fitted_values[0], medium_fitted_values[1])
plt.xlabel("Plant size [kW${_{el}}$]")
plt.ylabel("CAPEX [GBP]")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Models with sklearn

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
def get_polynomial_model_and_performance(dataset, display_fit=True):
    # Extract x and y data and sort it
    x = dataset["Plant size [kWel]"]
    y = dataset[currency_and_CEPCI_scaled_label]
    temp_sorting_df = pd.DataFrame({'x_sorted':x, 'y_sorted':y})
    temp_sorting_df = temp_sorting_df.sort_values('x_sorted')
    x = np.array(temp_sorting_df["x_sorted"])
    y = np.array(temp_sorting_df["y_sorted"])


    def fit_polynomial_regression_and_get_performance(degree):
        """
        Fits nth degree polynomial and returns regression models and its performance.

        Parameters
        ----------
        degree: int

        Returns
        -------

        """
        # Get polynomial features and fit regression model
        poly = PolynomialFeatures(degree=degree, include_bias=False)
        poly_features = poly.fit_transform(x.reshape(-1, 1))
        poly_reg_model = LinearRegression()
        poly_reg_model.fit(poly_features, y)
        y_predicted = poly_reg_model.predict(poly_features)

        # Get error scores
        model_r2 = r2_score(y, y_predicted)
        model_rmse = mean_squared_error(y, y_predicted, squared=False)

        return {"model": poly_reg_model, "R2": model_r2, "RMSE": model_rmse, "predictions": y_predicted, "degree": degree}

    # Check if 1st or 2nd degree polynomial performs better
    first_degree_results = fit_polynomial_regression_and_get_performance(degree=1)
    second_degree_results = fit_polynomial_regression_and_get_performance(degree=2)
    if first_degree_results["RMSE"] < second_degree_results["RMSE"]:
        results = first_degree_results
    else:
        results = second_degree_results


    if display_fit:
        # Plot with fit
        sns.scatterplot(data=dataset, x="Plant size [kWel]" ,y=currency_and_CEPCI_scaled_label, hue="Type")
        plt.plot(x, results["predictions"], c="red")
        plt.xlabel("Plant size [kW${_{el}}$]")
        plt.ylabel("CAPEX [GBP]")
        plt.xticks(rotation=45)
        plt.show()

    return results

df_small_results = get_polynomial_model_and_performance(df_small)
get_polynomial_model_and_performance(df_medium)
get_polynomial_model_and_performance(small_med_df)
# Out:
# {'model': LinearRegression(),
#  'R2': 0.9429352944238633,
#  'RMSE': 7056178.058105315,
#  'predictions': array([ 2847265.3387305 ,  2864546.52671136,  2872017.25320839,
#          2880684.3481545 ,  2882801.42743252,  2964750.75840893,
#          2992206.22898023, 10379432.87220879, 38783224.34071331,
#         40220810.22501941, 44455214.30140902, 73756635.29664269,
#         73756635.29664269, 73756635.29664269]),
#  'degree': 2}

# %% [markdown]
# ### Example model predictions

# %%
# Get individual predictions from model
df_small_results["model"].predict(PolynomialFeatures(degree=2, include_bias=False).fit_transform(np.array([200, 3999, 4999]).reshape(-1, 1)))
# Out:
# array([  658935.34037535, 13228957.64829205, 18909133.4675841 ])
