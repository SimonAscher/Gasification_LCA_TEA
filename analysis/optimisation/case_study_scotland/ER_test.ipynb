# %% [markdown]
# # Test variation in ER

# %%
from analysis.optimisation.helpers import run_optimisation
from analysis.optimisation.helpers import plot_optimisation_by_parameter

# %%
optimisation_parameters = {"ER": [0.250,0.275, 0.300, 0.325, 0.350]}


results, results_object_path, optimisation_combinations = run_optimisation(optimisation_parameters, relative_path_from_root="analysis\\optimisation\\case_study_scotland\\results")
# Out:
# Run optimisation using the following feedstock: Forestry residues (Phyllis #3155)
# Number of combinations considered in optimisation: 5
# 1 Failed download:
# ['GBP=X']: Exception("%ticker%: Data doesn't exist for startDate = 946684800, endDate = 978220800")
# ---------------------------------------------------------------------------
# RatesNotAvailableError                    Traceback (most recent call last)
# File ~\PycharmProjects\PhD_LCA_TEA\functions\TEA\currency_conversion.py:219, in get_average_annual_exchange_rate(year, base_currency, converted_currency, approximate_rate, method)
#     218 try:
# --> 219     historic_rates_array = run_with_yfinance()
#     220 except RatesNotAvailableError:  # slower but sometimes yfinance breaks
#
# File ~\PycharmProjects\PhD_LCA_TEA\functions\TEA\currency_conversion.py:206, in get_average_annual_exchange_rate.<locals>.run_with_yfinance()
#     205 if len(historic_rates_array) == 0:
# ...

# %%
plot_optimisation_by_parameter(results_object_path=results_object_path, highlighted_parameter="ER")
